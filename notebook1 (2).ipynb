# %%
# %%HTML
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link rel="icon" href="https://glitch.com/favicon.ico" />
#
#     <title>Furkan</title>
#
#     <!-- import the webpage's stylesheet -->
#     <link rel="stylesheet" href="/style.css" />
#
#     <!-- import the webpage's javascript file -->
#     <script src="/script.js" defer></script>
#   </head>
#   <body>
#     <!-- this is the start of content -->
#     <h1>
#       Accueil :
#     </h1>
#     <p>
#       Bienvenue sur le site que j'ai créer. Je suis passioné par les Animés et les Mangas.
#       J'ai découvert les animés a l'âge de 3-4 ans et depuis j'aimes les animés , en particulier Dragon Ball Z qui est mon préféré.
#        <img src= "https://cdn.glitch.me/eeb823e1-eb04-4005-9d70-ec984115ac56/goku.gif?v=1639665632906"/>
#                          Il y a aussi ce qui est appelé le "Big Three" , ce terme désigne les 3 mangas les plus connus/vendus
#       au début des années 2000 , les 3 mangas sont :
#        Bleach, One Piece et Naruto.      Ce que j'aime dans les Animés c'est en particulier l'animation , les combats , l'histoire , la musique pendant les combats , le scénario et dans le manga en général le dessin et l'histoire.
#        Les personnages sont la plupart du temps attachant , nous avons souvent hâte de savoir comment le héros principal va se débrouiller pour survivre
#        et vaincre ses adversaires.
#       Voici un des passages les plus connus dans Dragon Ball Z :
#       <iframe width="560" height="315" src="https://www.youtube.com/embed/lk7vlNKophY?start=90" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#       Voici le lien du site de mon ami Régis Théo
#       <a href= "https://theo-regis-crypto-monnai.glitch.me/"
#          >Lien de Théo</a
#     </p>
#   </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link rel="icon" href="https://glitch.com/favicon.ico" />
#
#     <title>Furkan</title>
#
#     <!-- import the webpage's stylesheet -->
#     <link rel="stylesheet" href="/style.css" />
#
#     <!-- import the webpage's javascript file -->
#     <script src="/script.js" defer></script>
#   </head>
#   <body>
#     <!-- this is the start of content -->
#     <h1>
#       Accueil :
#     </h1>
#     <p>
#       Bienvenue sur le site que j'ai créer. Je suis passioné par les Animés et les Mangas.
#       J'ai découvert les animés a l'âge de 3-4 ans et depuis j'aimes les animés , en particulier Dragon Ball Z qui est mon préféré.
#        <img src= "https://cdn.glitch.me/eeb823e1-eb04-4005-9d70-ec984115ac56/goku.gif?v=1639665632906"/>
# ...
